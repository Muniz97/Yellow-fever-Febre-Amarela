# %% [markdown]
# <a href="https://colab.research.google.com/github/Muniz97/Yellow-fever-Febre-Amarela/blob/main/Yellow_Fever.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Yellow Fever Brazil 1994-2021

# %%
'''
Conhecendo os dados
'''
# Out:
# '\nConhecendo os dados\n'

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/Muniz97/Yellow-fever-Febre-Amarela/main/fa_casoshumanos_1994-2021.csv'
#url = '/content/fa_casoshumanos_1994-2021.csv'

# %%
dados_raw = pd.read_csv(url, sep = ';', encoding="ISO-8859-1")

# %%
dados_raw.head(25)
# Out:
#     ID MACRORREG_LPI  COD_UF_LPI UF_LPI  COD_MUN_LPI  \
# 0    1             N          14     RR     140005.0
# 1    2             N          14     RR     140045.0
# 2    3            NE          21     MA     210060.0
# 3    4            NE          21     MA     210060.0
# 4    5             N          15     PA     150270.0
# 5    6             N          13     AM     130410.0
# 6    7             N          13     AM     130356.0
# 7    8             N          13     AM     130255.0
# 8    9             N          13     AM     130250.0
# 9   10             N          13     AM     130360.0
# 10  11             N          13     AM     130110.0
# 11  12             N          13     AM     130010.0
# 12  13             N          13     AM     130255.0
# 13  14             N          13     AM     130185.0
# 14  15             N          13     AM     130406.0
# 15  16             N          13     AM     130250.0
# 16  17             N          13     AM     130040.0
# ...

# %%
dados_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2758 entries, 0 to 2757
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                2758 non-null   int64
#  1   MACRORREG_LPI     2758 non-null   object
#  2   COD_UF_LPI        2758 non-null   int64
#  3   UF_LPI            2758 non-null   object
#  4   COD_MUN_LPI       2751 non-null   float64
#  5   MUN_LPI           2752 non-null   object
#  6   SEXO              2757 non-null   object
#  7   IDADE             2756 non-null   object
#  8   DT_IS             2753 non-null   object
#  9   SE_IS             2742 non-null   float64
#  10  MES_IS            2747 non-null   float64
#  11  ANO_IS            2758 non-null   int64
#  12  MONITORAMENTO_IS  2758 non-null   object
#  13  OBITO             2758 non-null   object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 301.8+ KB

# %%
dados_raw.isnull().sum()
# Out:
# ID                   0
# MACRORREG_LPI        0
# COD_UF_LPI           0
# UF_LPI               0
# COD_MUN_LPI          7
# MUN_LPI              6
# SEXO                 1
# IDADE                2
# DT_IS                5
# SE_IS               16
# MES_IS              11
# ANO_IS               0
# MONITORAMENTO_IS     0
# OBITO                0
# dtype: int64

# %%
dados_raw = dados_raw.dropna() # Por ser poucos valores nulos os mesmo foram desconsiderados
dados_raw.head()
# Out:
#    ID MACRORREG_LPI  COD_UF_LPI UF_LPI  COD_MUN_LPI                MUN_LPI  \
# 1   2             N          14     RR     140045.0              Pacaraima
# 2   3            NE          21     MA     210060.0   Amarante do Maranhão
# 3   4            NE          21     MA     210060.0   Amarante do Maranhão
# 4   5             N          15     PA     150270.0  Conceição do Araguaia
# 5   6             N          13     AM     130410.0                 Tapauá
#
#   SEXO IDADE       DT_IS  SE_IS  MES_IS  ANO_IS MONITORAMENTO_IS OBITO
# 1    M    19  19/02/1995    8.0     2.0    1995        1994/1995   NÃO
# 2    M    32  01/04/1995   13.0     4.0    1995        1994/1995   IGN
# 3    M    33  03/04/1995   14.0     4.0    1995        1994/1995   SIM
# 4    M    26  12/04/1995   15.0     4.0    1995        1994/1995   SIM
# 5    M    29  26/01/1996    4.0     1.0    1996        1995/1996   SIM
